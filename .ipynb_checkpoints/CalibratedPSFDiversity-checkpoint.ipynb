# %%
import numpy as np
from phasediv import PhaseDiv2
import matplotlib.pyplot as plt
# %matplotlib inline
import tifffile
from keras.models import Model
from keras.layers import *
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from scipy import signal

# %%
size_X = 512;
size_Y = 512;
p = PhaseDiv2(dshape = (size_Y,size_X),   # shape of the output stack (Nz,Ny,Nx)
              units = (.2,)*2,          # pixelsize (dz,dy,dx) in micron
              lam = 0.5,                # wavelength in micron
              NA=0.8,                 # Numerical Aperture of the detection obcejtive
              n = 1.33                  # refractive index of medium
              )

# %%
# Generating artificial image
img = np.zeros((size_Y,size_X))
img[4::8] = 1.
img[:,4::8] = 1.

print(img.shape)
plt.imshow(img)
# Out:
# (512, 512)

# %%
# Loading Beautiful Lena
img = tifffile.imread("/Users/dsaha/Desktop/lena-std.tif")

#Normalizing Lena
img = (img-np.min(img))/(np.max(img)-np.min(img))

#Replacing zeros with very small number
img[img==0] = 1e-10

#plt.imshow(img)
#plt.colorbar()

# %%
#The unknown aberation present in our image
abb = 0.0*p.zernike(4)

#Wavefront tuple contains the wavefront for the phase diversity images
wavefronts = (1*p.zernike(4)+abb,(-1*p.zernike(4))+abb)

#Generating the psfs and normalizing and storing them as a tuple
_psfs = tuple(np.fft.fftshift(p._psf_incoherent(w)) for w in wavefronts)
psfs = tuple((p-np.min(p))/(np.max(p)-np.min(p)) for p in _psfs)


#Generating the images where object is convolved with psf
images = tuple(np.fft.fftshift(p.myconvolve(img,psf)) for psf in psfs)


plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(img)
plt.title("Original Lena")
plt.axis("OFF")
for i,image in enumerate(images):
    plt.subplot(1,3,i+2)
    plt.imshow(image)
    #plt.colorbar()
    plt.title("Image with wavefront %s"%i)
    plt.axis("off")

# %%
#FFT of PSFs for two wavefronts
fftpsfs =  np.fft.fftshift(np.fft.fft2(psfs))

#FFT of Images for two wavefronts
fftimages = tuple(np.fft.fft2(image) for image in images)

#Representing the complex FFT info in amp and phase format
phase = tuple(np.angle(fftimage) for fftimage in fftimages)
amp = tuple(np.absolute(fftimage) for fftimage in fftimages)


#Dividing the FFT Images to get rid of the obejct
fftimage_amp_div = np.divide(amp[0],amp[1])
fftimage_phase_sub = np.subtract(phase[0],phase[1])
print(np.mean(fftimage_amp_div))
print(np.mean(fftimage_phase_sub))
# Out:
# 1.00893015648
# 1.19842250687e-05

# %%
#Generate multiple weights of aberrations

abb = 1*p.zernike(6)+2*p.zernike(8)

#Wavefront tuple contains the wavefront for the phase diversity images
wavefronts = (1*p.zernike(5)+abb,(-1*p.zernike(5))+abb)

#Generating the psfs and normalizing and storing them as a tuple
_psfs = tuple(np.fft.fftshift(p._psf_incoherent(w)) for w in wavefronts)
psfs = tuple((p-np.min(p))/(np.max(p)-np.min(p)) for p in _psfs)


#Generating the images where object is convolved with psf
images = tuple(np.fft.fftshift(p.myconvolve(img,psf)) for psf in psfs)

#FFT of PSFs for two wavefronts
fftpsfs =  np.fft.fftshift(np.fft.fft2(psfs))

#FFT of Images for two wavefronts
fftimages = tuple(np.fft.fft2(image) for image in images)

#Representing the complex FFT info in amp and phase format
phase = tuple(np.angle(fftimage) for fftimage in fftimages)
amp = tuple(np.absolute(fftimage) for fftimage in fftimages)


#Dividing the FFT Images to get rid of the obejct
fftimage_amp_div = np.divide(amp[0],amp[1])
fftimage_phase_sub = np.subtract(phase[0],phase[1])
fftimage_divide = np.divide(fftimages[0],fftimages[1])

#Going back to image
fftfftimage = np.fft.fftshift(np.fft.fft2(fftimage_divide))

plt.imshow(np.imag(fftfftimage))
plt.colorbar()
np.max(fftfftimage)
# Out:
# (155906.36784487622+2.0432527960098678e-06j)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,3,1)
wavefront = 2*p.zernike(5)
psf1 = np.fft.fftshift(p._psf_incoherent(wavefront))
plt.imshow(psf1)
plt.subplot(2,3,2)
wavefront = -2*p.zernike(5)
psf2 = np.fft.fftshift(p._psf_incoherent(wavefront))
plt.imshow(psf2)
plt.subplot(2,3,4)
wavefront = 2*p.zernike(5) + 0.5*p.zernike(7)
psf3 = np.fft.fftshift(p._psf_incoherent(wavefront))
plt.imshow(psf3)
plt.subplot(2,3,5)
wavefront = -2*p.zernike(5) + 0.5*p.zernike(7)
psf4 = np.fft.fftshift(p._psf_incoherent(wavefront))
plt.imshow(psf4)
plt.subplot(2,3,6)
plt.imshow(psf3[200:300,200:300]/psf4[200:300,200:300])
plt.subplot(2,3,3)
plt.imshow(psf2[200:300,200:300]/psf1[200:300,200:300])

# %%
#Generate multiple weights of aberrations

abb = -0.1*p.zernike(7)

#Wavefront tuple contains the wavefront for the phase diversity images
wavefronts = (1*p.zernike(5)+abb,(-1*p.zernike(5))+abb)

#Generating the psfs and normalizing and storing them as a tuple
_psfs = tuple(np.fft.fftshift(p._psf_incoherent(w)) for w in wavefronts)
psfs = tuple((p-np.min(p))/(np.max(p)-np.min(p)) for p in _psfs)


#Generating the images where object is convolved with psf
images = tuple(np.fft.fftshift(p.myconvolve(img,psf)) for psf in psfs)

#FFT of PSFs for two wavefronts
fftpsfs =  np.fft.fftshift(np.fft.fft2(psfs))

#FFT of Images for two wavefronts
fftimages = tuple(np.fft.fft2(image) for image in images)

#Representing the complex FFT info in amp and phase format
phase = tuple(np.angle(fftimage) for fftimage in fftimages)
amp = tuple(np.absolute(fftimage) for fftimage in fftimages)


#Dividing the FFT Images to get rid of the obejct
fftimage_amp_div = np.divide(amp[0],amp[1])
fftimage_phase_sub = np.subtract(phase[0],phase[1])
fftimage_divide = np.divide(fftimages[0],fftimages[1])

#Going back to image
fftfftimage = np.fft.fftshift(np.fft.fft2(fftimage_divide))

fftimage_amp_div[fftimage_amp_div<=1]= np.nan
plt.imshow(fftimage_amp_div)
plt.colorbar()

# %%
corr = np.corrcoef(images[0],images[1])
plt.imshow(corr)
plt.colorbar()

# %%
cross = signal.correlate2d(images[0],images[1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-388ff93a1706> in <module>()
# ----> 1 cross = signal.correlate2d(images[0],images[1])
#
# /Users/dsaha/anaconda/lib/python3.6/site-packages/scipy/signal/signaltools.py in correlate2d(in1, in2, mode, boundary, fillvalue)
#    1140         warnings.simplefilter('ignore', np.ComplexWarning)
#    1141         # FIXME: some cast generates a warning here
# -> 1142         out = sigtools._convolve2d(in1, in2, 0, val, bval, fillvalue)
#    1143
#    1144     if swapped_inputs:
#
# KeyboardInterrupt:
